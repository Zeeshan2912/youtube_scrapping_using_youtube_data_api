# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = 'AIzaSyB7qqymYIsWnvB6VAXbdRbyGQY9T9I0RqM'
channel_ids = ['UCD_IHEDvNMMk0Y9Kjbq3DaQ', # Nomadic_Tour
              'UCpunRuCSHQSKpyDRspHLEZQ', # Ishan_Goyal
              'UCK2_PiPOB0VEZfbbaHj-z5w', # Passenger_Paramvir
              'UCD8TJtF1r0xlEf7lNBR5Yzg', # Soul_Rover
              'UCen3UkSxLwY0TXNqF_tdCJQ'  # The_Indian_Polish_Connection
             ]

youtube = build('youtube', 'v3', developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids) :
    all_data = []
    request = youtube.channels().list(
                 part='snippet,contentDetails,statistics',
                 id= ','.join(channel_ids)) 
    response = request.execute()

    return response

# %%
get_channel_stats(youtube, channel_ids)
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'qlFJ587V7tUBCxaYhiQ3eyUEciM',
#  'pageInfo': {'totalResults': 5, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'XI2r-V3CcFFpdK3dBGZ8Rt2ArlQ',
#    'id': 'UCK2_PiPOB0VEZfbbaHj-z5w',
#    'snippet': {'title': 'Passenger Paramvir',
# ...
